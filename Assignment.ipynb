# %%
import pandas as pd

# %%
df=pd.read_csv('jsrt_metadata.csv',header=None)

# %%
df.head()
# Out:
#               0    1     2   3       4       5       6          7  \
# 0  JPCLN001.png  5.0  15.0  53    Male  1634.0   692.0  malignant
# 1  JPCLN002.png  5.0  30.0  78  Female  1614.0  1090.0     benign
# 2  JPCLN003.png  5.0  30.0  63  Female  1303.0   447.0  malignant
# 3  JPCLN004.png  5.0  14.0  68  Female   606.0   836.0     benign
# 4  JPCLN005.png  5.0  35.0  73  Female  1438.0   692.0  malignant
#
#                     8                   9
# 0        l.upper lobe         lung cancer
# 1    l.upper lobe(S5)  pulmonary hematoma
# 2  l.upper lobe(S1+2)         lung cancer
# 3        r.upper lobe   Inflammatory mass
# 4    l.upper lobe(S3)         lung cancer

# %%
header=["study_id","subtlety","size","age","gender","x","y","state","position","diagnosis"]

# %%
df.columns=header

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# 0          l.upper lobe         lung cancer
# 1      l.upper lobe(S5)  pulmonary hematoma
# 2    l.upper lobe(S1+2)         lung cancer
# 3          r.upper lobe   Inflammatory mass
# 4      l.upper lobe(S3)         lung cancer
# ..                  ...                 ...
# 242                 NaN                 NaN
# 243                 NaN                 NaN
# 244                 NaN                 NaN
# 245                 NaN                 NaN
# 246                 NaN                 NaN
#
# [247 rows x 10 columns]

# %%
import numpy as np

# %%
df.replace("?", np.nan, inplace=True)

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# 0          l.upper lobe         lung cancer
# 1      l.upper lobe(S5)  pulmonary hematoma
# 2    l.upper lobe(S1+2)         lung cancer
# 3          r.upper lobe   Inflammatory mass
# 4      l.upper lobe(S3)         lung cancer
# ..                  ...                 ...
# 242                 NaN                 NaN
# 243                 NaN                 NaN
# 244                 NaN                 NaN
# 245                 NaN                 NaN
# 246                 NaN                 NaN
#
# [247 rows x 10 columns]

# %%
df.isnull()
# Out:
#      study_id  subtlety   size    age  gender      x      y  state  position  \
# 0       False     False  False  False   False  False  False  False     False
# 1       False     False  False  False   False  False  False  False     False
# 2       False     False  False  False   False  False  False  False     False
# 3       False     False  False  False   False  False  False  False     False
# 4       False     False  False  False   False  False  False  False     False
# ..        ...       ...    ...    ...     ...    ...    ...    ...       ...
# 242     False      True   True  False   False   True   True  False      True
# 243     False      True   True  False   False   True   True  False      True
# 244     False      True   True  False   False   True   True  False      True
# 245     False      True   True  False   False   True   True  False      True
# 246     False      True   True  False   False   True   True  False      True
#
#      diagnosis
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# ..         ...
# 242       True
# 243       True
# 244       True
# 245       True
# 246       True
#
# [247 rows x 10 columns]

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           2
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
m=df['subtlety'].astype('float').mean()
df['subtlety'].replace(np.nan, m, inplace=True)

# %%
m=df['size'].astype('float').mean()
df['size'].replace(np.nan, m, inplace=True)

# %%
m=df['age'].astype('float').mean()
df['age'].replace(np.nan, m, inplace=True)

# %%
m=df['x'].astype('float').mean()
df['x'].replace(np.nan, m, inplace=True)

# %%
m=df['y'].astype('float').mean()
df['y'].replace(np.nan, m, inplace=True)

# %%
df['position'].head(247)
mx = df['position'].value_counts().idxmax()
df['position'].replace(np.nan, mx, inplace=True)

# %%
df['position'].head(247)
mx = df['diagnosis'].value_counts().idxmax()
df['diagnosis'].replace(np.nan, mx, inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %%
df
# Out:
#          study_id  subtlety       size age  gender            x            y  \
# 0    JPCLN001.png   5.00000  15.000000  53    Male  1634.000000   692.000000
# 1    JPCLN002.png   5.00000  30.000000  78  Female  1614.000000  1090.000000
# 2    JPCLN003.png   5.00000  30.000000  63  Female  1303.000000   447.000000
# 3    JPCLN004.png   5.00000  14.000000  68  Female   606.000000   836.000000
# 4    JPCLN005.png   5.00000  35.000000  73  Female  1438.000000   692.000000
# ..            ...       ...        ...  ..     ...          ...          ...
# 242  JPCNN089.png   2.88961  17.246753  50    Male   937.324675   868.623377
# 243  JPCNN090.png   2.88961  17.246753  68  Female   937.324675   868.623377
# 244  JPCNN091.png   2.88961  17.246753  81    Male   937.324675   868.623377
# 245  JPCNN092.png   2.88961  17.246753  70  Female   937.324675   868.623377
# 246  JPCNN093.png   2.88961  17.246753  41    Male   937.324675   868.623377
#
#           state            position           diagnosis
# 0     malignant        l.upper lobe         lung cancer
# 1        benign    l.upper lobe(S5)  pulmonary hematoma
# 2     malignant  l.upper lobe(S1+2)         lung cancer
# 3        benign        r.upper lobe   Inflammatory mass
# 4     malignant    l.upper lobe(S3)         lung cancer
# ..          ...                 ...                 ...
# 242  non-nodule    r.upper lobe(S2)         lung cancer
# 243  non-nodule    r.upper lobe(S2)         lung cancer
# 244  non-nodule    r.upper lobe(S2)         lung cancer
# 245  non-nodule    r.upper lobe(S2)         lung cancer
# 246  non-nodule    r.upper lobe(S2)         lung cancer
#
# [247 rows x 10 columns]

# %%
import matplotlib as plt
from matplotlib import pyplot

# %%
plt.pyplot.title("Diagnosis Pyplot")
plt.pyplot.xlabel("X-Axis")
plt.pyplot.ylabel("Y-Axis")
plt.pyplot.hist(df['diagnosis'].value_counts(), color='red',ec='black')
# Out:
# (array([30.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([  1. ,  15.8,  30.6,  45.4,  60.2,  75. ,  89.8, 104.6, 119.4,
#         134.2, 149. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pyplot.pie(df[['diagnosis', 'state']].value_counts(), shadow=True,autopct='%1.1f%%', startangle=30)
# Out:
# ([<matplotlib.patches.Wedge at 0x1fecfe0a070>,
#   <matplotlib.patches.Wedge at 0x1fed0636730>,
#   <matplotlib.patches.Wedge at 0x1fecf7d5820>,
#   <matplotlib.patches.Wedge at 0x1fecfe03940>,
#   <matplotlib.patches.Wedge at 0x1fecfdf4880>,
#   <matplotlib.patches.Wedge at 0x1fecfdeb640>,
#   <matplotlib.patches.Wedge at 0x1fecfdebaf0>,
#   <matplotlib.patches.Wedge at 0x1fecfdf51f0>,
#   <matplotlib.patches.Wedge at 0x1fece77fa90>,
#   <matplotlib.patches.Wedge at 0x1fecfcc5760>,
#   <matplotlib.patches.Wedge at 0x1fed06fc460>,
#   <matplotlib.patches.Wedge at 0x1fecfcbdca0>,
#   <matplotlib.patches.Wedge at 0x1fecfca22e0>,
#   <matplotlib.patches.Wedge at 0x1fecf90baf0>,
#   <matplotlib.patches.Wedge at 0x1fecfcd1340>,
#   <matplotlib.patches.Wedge at 0x1fecfcd1d90>,
#   <matplotlib.patches.Wedge at 0x1fecfca87c0>,
#   <matplotlib.patches.Wedge at 0x1fecfca8130>,
#   <matplotlib.patches.Wedge at 0x1fed09e09a0>,
#   <matplotlib.patches.Wedge at 0x1fed07e3370>,
#   <matplotlib.patches.Wedge at 0x1fed07e3d00>,
#   <matplotlib.patches.Wedge at 0x1fed07fe6d0>,
#   <matplotlib.patches.Wedge at 0x1fed07f80a0>,
#   <matplotlib.patches.Wedge at 0x1fed07f8a30>,
#   <matplotlib.patches.Wedge at 0x1fed07341c0>,
#   <matplotlib.patches.Wedge at 0x1fed0734b50>,
#   <matplotlib.patches.Wedge at 0x1fed0741520>,
#   <matplotlib.patches.Wedge at 0x1fed0741eb0>,
#   <matplotlib.patches.Wedge at 0x1fed0721880>,
#   <matplotlib.patches.Wedge at 0x1fed0828250>,
#   <matplotlib.patches.Wedge at 0x1fed0828be0>,
#   <matplotlib.patches.Wedge at 0x1fed083f970>,
#   <matplotlib.patches.Wedge at 0x1fed083fc10>],
#  [Text(-0.1487788639238769, 1.0898921275289224, ''),
#   Text(-0.9856558994120178, -0.4883466473257355, ''),
#   Text(-0.11637264781578889, -1.0938269547055157, ''),
#   Text(0.3922447752963583, -1.0276886864477537, ''),
#   Text(0.6608164843283796, -0.8793870445030907, ''),
#   Text(0.815584313582012, -0.7381207404205349, ''),
#   Text(0.9105481325740359, -0.6171726648725916, ''),
#   Text(0.9685287726548254, -0.5214901883446492, ''),
#   Text(1.0164904300758535, -0.42041313676454795, ''),
#   Text(1.0498455029270728, -0.32836628935352286, ''),
#   Text(1.0685916403326114, -0.26098257836732847, ''),
#   Text(1.0804810062920722, -0.20630267822321466, ''),
#   Text(1.0895742941249749, -0.1510889062177076, ''),
#   Text(1.0958479721421366, -0.09548414502925262, ''),
#   Text(1.0992858052651298, -0.03963228914149741, ''),
#   Text(1.0998788970395588, 0.01632212752810279, ''),
#   Text(1.0976257126573818, 0.07223430565441218, ''),
#   Text(1.0925320829287002, 0.127959555217561, ''),
#   Text(1.0868554722606705, 0.16954404270582724, ''),
#   Text(1.082191447756454, 0.1971336358990775, ''),
#   Text(1.0768271838731114, 0.22459567242470285, ''),
#   Text(1.0707661515942828, 0.25191238278411315, ''),
#   Text(1.0640122727523655, 0.2790660915130072, ''),
#   Text(1.0565699174908647, 0.3060392286184039, ''),
#   Text(1.0484439014366627, 0.3328143409474263, ''),
#   Text(1.0396394825840345, 0.35937410348048365, ''),
#   Text(1.030162357892426, 0.3857013305415439, ''),
#   Text(1.0200186596001986, 0.4117789869182427, ''),
#   Text(1.0092149512567212, 0.43759019888463424, ''),
#   Text(0.9977582234753815, 0.46311826511945203, ''),
#   Text(0.9856558894102616, 0.48834666751280936, ''),
#   Text(0.9729157799594058, 0.5132590818543606, ''),
#   Text(0.9595461386977843, 0.53783938839599, '')],
#  [Text(-0.08115210759484194, 0.5944866150157757, '37.7%'),
#   Text(-0.5376304905883733, -0.26637089854131024, '22.7%'),
#   Text(-0.06347598971770303, -0.5966328843848268, '9.3%'),
#   Text(0.21395169561619543, -0.5605574653351383, '5.7%'),
#   Text(0.360445355088207, -0.4796656606380494, '3.2%'),
#   Text(0.44486417104473375, -0.40261131295665537, '2.8%'),
#   Text(0.49666261776765586, -0.33663963538504993, '1.6%'),
#   Text(0.5282884214480865, -0.2844491936425359, '1.6%'),
#   Text(0.5544493254959201, -0.22931625641702613, '1.6%'),
#   Text(0.5726430015965851, -0.17910888510192152, '1.2%'),
#   Text(0.5828681674541517, -0.1423541336549064, '0.8%'),
#   Text(0.5893532761593121, -0.11252873357629889, '0.8%'),
#   Text(0.5943132513408953, -0.08241213066420414, '0.8%'),
#   Text(0.5977352575320743, -0.052082260925046885, '0.8%'),
#   Text(0.5996104392355253, -0.021617612258998584, '0.8%'),
#   Text(0.5999339438397593, 0.00890297865169243, '0.8%'),
#   Text(0.5987049341767536, 0.039400530356952096, '0.8%'),
#   Text(0.5959265906883818, 0.06979612102776055, '0.8%'),
#   Text(0.5928302575967292, 0.09247856874863303, '0.4%'),
#   Text(0.5902862442307931, 0.10752743776313317, '0.4%'),
#   Text(0.5873602821126062, 0.12250673041347426, '0.4%'),
#   Text(0.5840542645059723, 0.13740675424587986, '0.4%'),
#   Text(0.5803703305921993, 0.15221786809800392, '0.4%'),
#   Text(0.5763108640859261, 0.1669304883373112, '0.4%'),
#   Text(0.5718784916927251, 0.1815350950622325, '0.4%'),
#   Text(0.5670760814094733, 0.19602223826208195, '0.4%'),
#   Text(0.5619067406685959, 0.21038254393175118, '0.4%'),
#   Text(0.556373814327381, 0.22460672013722327, '0.4%'),
#   Text(0.5504808825036661, 0.23868556302798227, '0.4%'),
#   Text(0.5442317582592989, 0.25260996279242837, '0.4%'),
#   Text(0.5376304851328699, 0.2663709095524414, '0.4%'),
#   Text(0.5306813345233122, 0.27995949919328755, '0.4%'),
#   Text(0.5233888029260642, 0.2933669391250854, '0.4%')])

# %%
plt.pyplot.pie(df[['diagnosis', 'gender']].value_counts(),shadow=True,autopct='%1.1f%%', startangle=30)
# Out:
# ([<matplotlib.patches.Wedge at 0x1fed04d3f10>,
#   <matplotlib.patches.Wedge at 0x1fed04e2970>,
#   <matplotlib.patches.Wedge at 0x1fed04ed340>,
#   <matplotlib.patches.Wedge at 0x1fed04edcd0>,
#   <matplotlib.patches.Wedge at 0x1fed04f96a0>,
#   <matplotlib.patches.Wedge at 0x1fed04f9fd0>,
#   <matplotlib.patches.Wedge at 0x1fed0509a00>,
#   <matplotlib.patches.Wedge at 0x1fed05163d0>,
#   <matplotlib.patches.Wedge at 0x1fed0516d60>,
#   <matplotlib.patches.Wedge at 0x1fed0524730>,
#   <matplotlib.patches.Wedge at 0x1fed04a6ca0>,
#   <matplotlib.patches.Wedge at 0x1fed0532a60>,
#   <matplotlib.patches.Wedge at 0x1fed0540430>,
#   <matplotlib.patches.Wedge at 0x1fed0540dc0>,
#   <matplotlib.patches.Wedge at 0x1fed054d790>,
#   <matplotlib.patches.Wedge at 0x1fed055b160>,
#   <matplotlib.patches.Wedge at 0x1fed055baf0>,
#   <matplotlib.patches.Wedge at 0x1fed05684c0>,
#   <matplotlib.patches.Wedge at 0x1fed0568e50>,
#   <matplotlib.patches.Wedge at 0x1fed0575850>,
#   <matplotlib.patches.Wedge at 0x1fed0585220>,
#   <matplotlib.patches.Wedge at 0x1fed0585bb0>,
#   <matplotlib.patches.Wedge at 0x1fed0591580>,
#   <matplotlib.patches.Wedge at 0x1fed0591f10>,
#   <matplotlib.patches.Wedge at 0x1fed059e730>,
#   <matplotlib.patches.Wedge at 0x1fed05ae100>,
#   <matplotlib.patches.Wedge at 0x1fed05aea90>,
#   <matplotlib.patches.Wedge at 0x1fed05ba460>,
#   <matplotlib.patches.Wedge at 0x1fed05badf0>,
#   <matplotlib.patches.Wedge at 0x1fed05c97c0>,
#   <matplotlib.patches.Wedge at 0x1fed05d6190>,
#   <matplotlib.patches.Wedge at 0x1fed05d6b20>,
#   <matplotlib.patches.Wedge at 0x1fed05e54f0>,
#   <matplotlib.patches.Wedge at 0x1fed05e5eb0>,
#   <matplotlib.patches.Wedge at 0x1fed05f3880>,
#   <matplotlib.patches.Wedge at 0x1fed0601250>,
#   <matplotlib.patches.Wedge at 0x1fed0601be0>,
#   <matplotlib.patches.Wedge at 0x1fed060e5b0>,
#   <matplotlib.patches.Wedge at 0x1fed060ef40>,
#   <matplotlib.patches.Wedge at 0x1fed061c910>,
#   <matplotlib.patches.Wedge at 0x1fed06292e0>,
#   <matplotlib.patches.Wedge at 0x1fed0629c70>],
#  [Text(0.10245119097379463, 1.0952185870720288, ''),
#   Text(-1.0707661375902484, -0.251912442308953, ''),
#   Text(-0.22687775139954272, -1.076348682314373, ''),
#   Text(0.10709373615321648, -1.0947743747808247, ''),
#   Text(0.33947521328644964, -1.0463061595747776, ''),
#   Text(0.5194359824637065, -0.9696320230489318, ''),
#   Text(0.6495784983503219, -0.8877205497683045, ''),
#   Text(0.7467236985427826, -0.8077151218310745, ''),
#   Text(0.8249063187734428, -0.7276878212857815, ''),
#   Text(0.8863416773213636, -0.6514586948096955, ''),
#   Text(0.9334291529870983, -0.5819879864342464, ''),
#   Text(0.975083137794939, -0.5091295261404274, ''),
#   Text(1.005468295796911, -0.4461317138998928, ''),
#   Text(1.0268549208856008, -0.3944223262608581, ''),
#   Text(1.0455842418970174, -0.34169224910237533, ''),
#   Text(1.061607790931678, -0.28807793777580926, ''),
#   Text(1.074884102110308, -0.23371813586137702, ''),
#   Text(1.0853788188796025, -0.17875351612631094, ''),
#   Text(1.0930647829204125, -0.12332631649064918, ''),
#   Text(1.0979221044282799, -0.06757997194271091, ''),
#   Text(1.0997009611221205, -0.025647536082139443, ''),
#   Text(1.099997528214147, 0.0023319354122409057, ''),
#   Text(1.0995823343808824, 0.030309898011860893, ''),
#   Text(1.0984556482763366, 0.05826824838463394, ''),
#   Text(1.0966181989304604, 0.08618889588869999, ''),
#   Text(1.094071175277423, 0.11405377427809517, ''),
#   Text(1.0908162253863016, 0.1418448533926457, ''),
#   Text(1.0868554553946899, 0.16954415082450236, ''),
#   Text(1.0821914281459044, 0.19713374355378166, ''),
#   Text(1.0768271615306815, 0.22459577954577836, ''),
#   Text(1.0707661265344295, 0.2519124893022465, ''),
#   Text(1.0640122449913039, 0.2790661973592752, ''),
#   Text(1.0565698870465576, 0.30603933372431796, ''),
#   Text(1.0484438683288098, 0.3328144452449769, ''),
#   Text(1.0396394468340577, 0.3593742069021853, ''),
#   Text(1.0301623195234582, 0.38570143302047594, ''),
#   Text(1.0200186186370666, 0.4117790883880954, ''),
#   Text(1.0092149077259305, 0.4375902992797509, ''),
#   Text(0.997758177405099, 0.46311836437487036, ''),
#   Text(0.9856558408302973, 0.4883467655643064, ''),
#   Text(0.9729157289011938, 0.5132591786384915, ''),
#   Text(0.9595460851943621, 0.5378394838501297, '')],
#  [Text(0.05588246780388797, 0.597391956584743, '30.4%'),
#   Text(-0.5840542568674081, -0.13740678671397435, '30.0%'),
#   Text(-0.12375150076338692, -0.5870992812623853, '6.1%'),
#   Text(0.0584147651744817, -0.5971496589713589, '3.6%'),
#   Text(0.18516829815624522, -0.5707124506771513, '3.2%'),
#   Text(0.28332871770747625, -0.5288901943903264, '2.4%'),
#   Text(0.35431554455472103, -0.4842112089645297, '2.0%'),
#   Text(0.40730383556879046, -0.4405718846351315, '1.6%'),
#   Text(0.44994890114915054, -0.3969206297922444, '1.6%'),
#   Text(0.4834590967207437, -0.3553411062598339, '1.2%'),
#   Text(0.509143174356599, -0.31744799260049805, '1.2%'),
#   Text(0.5318635297063303, -0.27770701425841493, '1.2%'),
#   Text(0.5484372522528604, -0.24334457121812333, '0.8%'),
#   Text(0.5601026841194185, -0.21513945068774076, '0.8%'),
#   Text(0.570318677398373, -0.18637759041947743, '0.8%'),
#   Text(0.5790587950536424, -0.15713342060498683, '0.8%'),
#   Text(0.5863004193328952, -0.1274826195607511, '0.8%'),
#   Text(0.5920248102979649, -0.09750191788707868, '0.8%'),
#   Text(0.5962171543202249, -0.06726889990399046, '0.8%'),
#   Text(0.5988666024154253, -0.03686180287784231, '0.8%'),
#   Text(0.599836887884793, -0.013989565135712421, '0.4%'),
#   Text(0.599998651753171, 0.0012719647703132212, '0.4%'),
#   Text(0.5997721823895722, 0.016532671642833213, '0.4%'),
#   Text(0.5991576263325471, 0.03178268093707305, '0.4%'),
#   Text(0.5981553812347965, 0.04701212503019999, '0.4%'),
#   Text(0.596766095605867, 0.06221114960623372, '0.4%'),
#   Text(0.5949906683925281, 0.07736992003235219, '0.4%'),
#   Text(0.5928302483971034, 0.09247862772245583, '0.4%'),
#   Text(0.5902862335341296, 0.1075274964838809, '0.4%'),
#   Text(0.5873602699258262, 0.12250678884315182, '0.4%'),
#   Text(0.5840542508369614, 0.13740681234667992, '0.4%'),
#   Text(0.580370315449802, 0.1522179258323319, '0.4%'),
#   Text(0.5763108474799404, 0.16693054566780977, '0.4%'),
#   Text(0.5718784736338962, 0.18153515195180556, '0.4%'),
#   Text(0.5670760619094859, 0.19602229467391924, '0.4%'),
#   Text(0.561906719740068, 0.21038259982935048, '0.4%'),
#   Text(0.5563737919838544, 0.22460677548441565, '0.4%'),
#   Text(0.5504808587595983, 0.238685617788955, '0.4%'),
#   Text(0.5442317331300539, 0.25261001693174745, '0.4%'),
#   Text(0.5376304586347076, 0.2663709630350762, '0.4%'),
#   Text(0.5306813066733784, 0.2799595519846317, '0.4%'),
#   Text(0.5233887737423794, 0.2933669911909798, '0.4%')])
