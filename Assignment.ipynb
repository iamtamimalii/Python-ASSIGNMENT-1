# %%
import pandas as pd
import numpy as np
import matplotlib as plt
from matplotlib import pyplot

# %%
df=pd.read_csv('jsrt_metadata.csv')

# %%
df.replace("?", np.nan, inplace=True)

# %%
df
# Out:
#          study_id  subtlety  size age  gender       x       y       state  \
# 0    JPCLN001.png       5.0  15.0  53    Male  1634.0   692.0   malignant
# 1    JPCLN002.png       5.0  30.0  78  Female  1614.0  1090.0      benign
# 2    JPCLN003.png       5.0  30.0  63  Female  1303.0   447.0   malignant
# 3    JPCLN004.png       5.0  14.0  68  Female   606.0   836.0      benign
# 4    JPCLN005.png       5.0  35.0  73  Female  1438.0   692.0   malignant
# ..            ...       ...   ...  ..     ...     ...     ...         ...
# 242  JPCNN089.png       NaN   NaN  50    Male     NaN     NaN  non-nodule
# 243  JPCNN090.png       NaN   NaN  68  Female     NaN     NaN  non-nodule
# 244  JPCNN091.png       NaN   NaN  81    Male     NaN     NaN  non-nodule
# 245  JPCNN092.png       NaN   NaN  70  Female     NaN     NaN  non-nodule
# 246  JPCNN093.png       NaN   NaN  41    Male     NaN     NaN  non-nodule
#
#                position           diagnosis
# ...

# %%
df.isnull()
# Out:
#      study_id  subtlety   size    age  gender      x      y  state  position  \
# 0       False     False  False  False   False  False  False  False     False
# 1       False     False  False  False   False  False  False  False     False
# 2       False     False  False  False   False  False  False  False     False
# 3       False     False  False  False   False  False  False  False     False
# 4       False     False  False  False   False  False  False  False     False
# ..        ...       ...    ...    ...     ...    ...    ...    ...       ...
# 242     False      True   True  False   False   True   True  False      True
# 243     False      True   True  False   False   True   True  False      True
# 244     False      True   True  False   False   True   True  False      True
# 245     False      True   True  False   False   True   True  False      True
# 246     False      True   True  False   False   True   True  False      True
#
#      diagnosis
# 0        False
# ...

# %%
df.isnull().sum()
# Out:
# study_id      0
# subtlety     93
# size         93
# age           2
# gender        0
# x            93
# y            93
# state         0
# position     93
# diagnosis    93
# dtype: int64

# %%
m=df['subtlety'].astype('float').mean()
df['subtlety'].replace(np.nan, m, inplace=True)

# %%
m=df['size'].astype('float').mean()
df['size'].replace(np.nan, m, inplace=True)

# %%
m=df['age'].astype('float').mean()
df['age'].replace(np.nan, m, inplace=True)

# %%
m=df['x'].astype('float').mean()
df['x'].replace(np.nan, m, inplace=True)

# %%
m=df['y'].astype('float').mean()
df['y'].replace(np.nan, m, inplace=True)

# %%
df['position'].head(247)
mx = df['position'].value_counts().idxmax()
df['position'].replace(np.nan, mx, inplace=True)

# %%
df['position'].head(247)
mx = df['diagnosis'].value_counts().idxmax()
df['diagnosis'].replace(np.nan, mx, inplace=True)

# %%
df.isnull().sum()
# Out:
# study_id     0
# subtlety     0
# size         0
# age          0
# gender       0
# x            0
# y            0
# state        0
# position     0
# diagnosis    0
# dtype: int64

# %%
df
# Out:
#          study_id  subtlety       size age  gender            x            y  \
# 0    JPCLN001.png   5.00000  15.000000  53    Male  1634.000000   692.000000
# 1    JPCLN002.png   5.00000  30.000000  78  Female  1614.000000  1090.000000
# 2    JPCLN003.png   5.00000  30.000000  63  Female  1303.000000   447.000000
# 3    JPCLN004.png   5.00000  14.000000  68  Female   606.000000   836.000000
# 4    JPCLN005.png   5.00000  35.000000  73  Female  1438.000000   692.000000
# ..            ...       ...        ...  ..     ...          ...          ...
# 242  JPCNN089.png   2.88961  17.246753  50    Male   937.324675   868.623377
# 243  JPCNN090.png   2.88961  17.246753  68  Female   937.324675   868.623377
# 244  JPCNN091.png   2.88961  17.246753  81    Male   937.324675   868.623377
# 245  JPCNN092.png   2.88961  17.246753  70  Female   937.324675   868.623377
# 246  JPCNN093.png   2.88961  17.246753  41    Male   937.324675   868.623377
#
# ...

# %%
plt.pyplot.title("Diagnosis Pyplot")
plt.pyplot.xlabel("X-Axis")
plt.pyplot.ylabel("Y-Axis")
plt.pyplot.hist(df['diagnosis'].value_counts(), color='red',ec='black')
# Out:
# (array([30.,  1.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([  1. ,  15.8,  30.6,  45.4,  60.2,  75. ,  89.8, 104.6, 119.4,
#         134.2, 149. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.pyplot.pie(df[['diagnosis', 'state']].value_counts(),autopct='%1.1f%%', startangle=30)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e3545f2e80>,
# ...
#  [Text(-0.1487788639238769, 1.0898921275289224, ''),
#   Text(-0.9856558994120178, -0.4883466473257355, ''),
#   Text(-0.11637264781578889, -1.0938269547055157, ''),
#   Text(0.3922447752963583, -1.0276886864477537, ''),
#   Text(0.6608164843283796, -0.8793870445030907, ''),
#   Text(0.815584313582012, -0.7381207404205349, ''),
#   Text(0.9105481325740359, -0.6171726648725916, ''),
#   Text(0.9685287726548254, -0.5214901883446492, ''),
#   Text(1.0164904300758535, -0.42041313676454795, ''),
#   Text(1.0498455029270728, -0.32836628935352286, ''),
#   Text(1.0685916403326114, -0.26098257836732847, ''),
#   Text(1.0804810062920722, -0.20630267822321466, ''),
#   Text(1.0895742941249749, -0.1510889062177076, ''),
#   Text(1.0958479721421366, -0.09548414502925262, ''),
#   Text(1.0992858052651298, -0.03963228914149741, ''),
#   Text(1.0998788970395588, 0.01632212752810279, ''),
#   Text(1.0976257126573818, 0.07223430565441218, ''),
# ...

# %%
plt.pyplot.pie(df[['diagnosis', 'gender']].value_counts(),
               explode=[0,0,0,0,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3,3], 
               labels=['lung cancer','pulmonary hematoma','lung cancer(adenocarcinoma)','tuberculoma','lung cancer(adenocarcinoma)','granuloma','tuberculoma','unknown','lung cancer(bronchioloalveolar cell carcinoma)','pulmonary tuberculosis','lung cancer(bronchioloalveolar cell carcinoma)','metastasis of colon cancer','Cryptococcosis','hamartoma','inflammatory mass','granuloma','sclerosing hemangioma','lung cancer(squamous cell carcinoma)','Inflammatory mass','susp. inflammatory mass','susp. hamartoma','susp. inflammatory mass','susp. sclerosing hemangioma','susp. lung metastasis','pulmonary hematoma','susp.tuberculoma','calcified granuloma','pulmonary hematoma','lung abscess','pneumonia','lung abscess','organiging pneumonia','metastatic lung cancer','metastasis of uterine cancer','metastasis of ovarian cancer','metastasis of colon cancer','lung canceror metastasis','lung cancer(small cell carcinoma)','lung cancer(large cell carcinoma)','unknown','lung cancer(adenosquamous carcinoma)','organizing pneumonia'],
               autopct='%1.1f%%', startangle=30)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e355cf7040>,
# ...
#  [Text(0.10245119097379463, 1.0952185870720288, 'lung cancer'),
#   Text(-1.0707661375902484, -0.251912442308953, 'pulmonary hematoma'),
#   Text(-0.22687775139954272, -1.076348682314373, 'lung cancer(adenocarcinoma)'),
#   Text(0.10709373615321648, -1.0947743747808247, 'tuberculoma'),
#   Text(1.2653167040676758, -3.899868412960534, 'lung cancer(adenocarcinoma)'),
#   Text(1.9360795710010876, -3.614082995000564, 'granuloma'),
#   Text(2.421156221123927, -3.3087765945909533, 'tuberculoma'),
#   Text(2.7832428763867347, -3.0105745450067323, 'unknown'),
#   Text(3.0746508245191952, -2.7122909702470035, 'lung cancer(bronchioloalveolar cell carcinoma)'),
#   Text(3.3036371609250823, -2.428164226108865, 'pulmonary tuberculosis'),
#   Text(3.4791450247700935, -2.1692279494367366, 'lung cancer(bronchioloalveolar cell carcinoma)'),
#   Text(3.634400786326591, -1.897664597432502, 'metastasis of colon cancer'),
# ...

# %%
plt.pyplot.pie(df["state"].value_counts(),labels=['malignant','benign','non-nodule'],autopct='%1.1f%%', startangle=30)
# Out:
# ([<matplotlib.patches.Wedge at 0x1e355fc98b0>,
# ...
#  [Text(-0.24509775237015996, 1.072346535306146, 'malignant'),
#   Text(-0.49043502210806916, -0.9846184484813688, 'benign'),
#   Text(1.0853787958674395, -0.17875365585449562, 'non-nodule')],
#  [Text(-0.13368968311099633, 0.5849162919851706, '40.5%'),
#   Text(-0.26751001205894676, -0.5370646082625647, '37.7%'),
#   Text(0.592024797745876, -0.09750199410245215, '21.9%')])
